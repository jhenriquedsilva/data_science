# %%
import requests
url = "https://api.covid19api.com/dayone/country/brazil"
answer = requests.get(url)

# %%
raw_data = answer.json()
print(raw_data[-1])
# Out:
# {'ID': '84b98381-a7dd-46dd-9606-c2296b1b1b46', 'Country': 'Brazil', 'CountryCode': 'BR', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '-14.24', 'Lon': '-51.93', 'Confirmed': 19342448, 'Deaths': 541266, 'Recovered': 17254329, 'Active': 1546853, 'Date': '2021-07-17T00:00:00Z'}

# %%
final_data = []
for obs in raw_data:
    final_data.append([obs["Confirmed"], obs["Deaths"], obs["Recovered"], obs["Active"], obs["Date"]])

final_data.insert(0, ["Confirmados", "Óbitos", "Recuperados", "Ativos", "Data"])
print(final_data)
# Out:
# [['Confirmados', 'Óbitos', 'Recuperados', 'Ativos', 'Data'], [1, 0, 0, 1, '2020-02-26T00:00:00Z'], [1, 0, 0, 1, '2020-02-27T00:00:00Z'], [1, 0, 0, 1, '2020-02-28T00:00:00Z'], [2, 0, 0, 2, '2020-02-29T00:00:00Z'], [2, 0, 0, 2, '2020-03-01T00:00:00Z'], [2, 0, 0, 2, '2020-03-02T00:00:00Z'], [2, 0, 0, 2, '2020-03-03T00:00:00Z'], [4, 0, 0, 4, '2020-03-04T00:00:00Z'], [4, 0, 0, 4, '2020-03-05T00:00:00Z'], [13, 0, 0, 13, '2020-03-06T00:00:00Z'], [13, 0, 0, 13, '2020-03-07T00:00:00Z'], [20, 0, 0, 20, '2020-03-08T00:00:00Z'], [25, 0, 0, 25, '2020-03-09T00:00:00Z'], [31, 0, 0, 31, '2020-03-10T00:00:00Z'], [38, 0, 0, 38, '2020-03-11T00:00:00Z'], [52, 0, 0, 52, '2020-03-12T00:00:00Z'], [151, 0, 0, 151, '2020-03-13T00:00:00Z'], [151, 0, 0, 151, '2020-03-14T00:00:00Z'], [162, 0, 0, 162, '2020-03-15T00:00:00Z'], [200, 0, 1, 199, '2020-03-16T00:00:00Z'], [321, 1, 2, 318, '2020-03-17T00:00:00Z'], [372, 3, 2, 367, '2020-03-18T00:00:00Z'], [621, 6, 2, 613, '2020-03-19T00:00:00Z'], [793, 11, 2, 780, '20
# ...

# %%
CONFIRMADOS = 0
OBITOS = 1
RECUPERADOS = 2
ATIVOS = 3
DATA = 4

for i in range(1, len(final_data)):
    final_data[i][DATA] = final_data[i][DATA][:10]
                    
for row in final_data:
    print(row)
# Out:
# ['Confirmados', 'Óbitos', 'Recuperados', 'Ativos', 'Data']
# [1, 0, 0, 1, '2020-02-26']
# [1, 0, 0, 1, '2020-02-27']
# [1, 0, 0, 1, '2020-02-28']
# [2, 0, 0, 2, '2020-02-29']
# [2, 0, 0, 2, '2020-03-01']
# [2, 0, 0, 2, '2020-03-02']
# [2, 0, 0, 2, '2020-03-03']
# [4, 0, 0, 4, '2020-03-04']
# [4, 0, 0, 4, '2020-03-05']
# [13, 0, 0, 13, '2020-03-06']
# [13, 0, 0, 13, '2020-03-07']
# [20, 0, 0, 20, '2020-03-08']
# [25, 0, 0, 25, '2020-03-09']
# [31, 0, 0, 31, '2020-03-10']
# [38, 0, 0, 38, '2020-03-11']
# [52, 0, 0, 52, '2020-03-12']
# [151, 0, 0, 151, '2020-03-13']
# [151, 0, 0, 151, '2020-03-14']
# [162, 0, 0, 162, '2020-03-15']
# [200, 0, 1, 199, '2020-03-16']
# [321, 1, 2, 318, '2020-03-17']
# [372, 3, 2, 367, '2020-03-18']
# [621, 6, 2, 613, '2020-03-19']
# [793, 11, 2, 780, '2020-03-20']
# [1021, 15, 2, 1004, '2020-03-21']
# [1546, 25, 2, 1519, '2020-03-22']
# [1924, 34, 2, 1888, '2020-03-23']
# [2247, 46, 2, 2199, '2020-03-24']
# [2554, 59, 2, 2493, '2020-03-25']
# ...

# %%
import datetime as dt
# Big to small. That's the rule
print(dt.time(12,5,45,3)) # Hora, minuto, segundo e microssrgundo
print(dt.date(1234,6,9)) # Ano, mês e dia
print(dt.datetime(1234,6,9,12,5,45,3)) # Junta os dois anteriores
# Out:
# 12:05:45.000003
# 1234-06-09
# 1234-06-09 12:05:45.000003

# %%
natal = dt.date(2020,12,25)
reveillon = dt.date(2021,1,1)
print((reveillon - natal))
print((reveillon - natal).microseconds)
print((reveillon - natal).seconds)
print((reveillon - natal).days)
# Out:
# 7 days, 0:00:00
# 0
# 0
# 7

# %%
import csv
with open("brasil-covid.csv","w") as file:
    writer = csv.writer(file)
    writer.writerows(final_data)

# %%
for i in range(1,len(final_data)):
    final_data[i][DATA] = dt.datetime.strptime(final_data[i][DATA], "%Y-%m-%d") # String to date

# %%
final_data
# Out:
# [['Confirmados', 'Óbitos', 'Recuperados', 'Ativos', 'Data'],
#  [1, 0, 0, 1, datetime.datetime(2020, 2, 26, 0, 0)],
#  [1, 0, 0, 1, datetime.datetime(2020, 2, 27, 0, 0)],
#  [1, 0, 0, 1, datetime.datetime(2020, 2, 28, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 2, 29, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 1, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 2, 0, 0)],
#  [2, 0, 0, 2, datetime.datetime(2020, 3, 3, 0, 0)],
#  [4, 0, 0, 4, datetime.datetime(2020, 3, 4, 0, 0)],
#  [4, 0, 0, 4, datetime.datetime(2020, 3, 5, 0, 0)],
#  [13, 0, 0, 13, datetime.datetime(2020, 3, 6, 0, 0)],
#  [13, 0, 0, 13, datetime.datetime(2020, 3, 7, 0, 0)],
#  [20, 0, 0, 20, datetime.datetime(2020, 3, 8, 0, 0)],
#  [25, 0, 0, 25, datetime.datetime(2020, 3, 9, 0, 0)],
#  [31, 0, 0, 31, datetime.datetime(2020, 3, 10, 0, 0)],
#  [38, 0, 0, 38, datetime.datetime(2020, 3, 11, 0, 0)],
#  [52, 0, 0, 52, datetime.datetime(2020, 3, 12, 0, 0)],
# ...

# %%
def get_datasets(data, label):
    if type(data[0] == list):
        datasets = []
        for i in range(len(data)):
            datasets.append({"labels": label[i], "data": data[i]})
        return datasets
    else:
        return [
            {
                "labels": label[0],
                "data": data
            }
        ]

# %%
def set_title(title=""):
    if title != "":
        display = "true"
    else:
        display = "false"
    return {
        "title": title,
        "display": display
    }

# %%
def create_chart(labels,data,label,kind="bar",title=""):
    datasets = get_datasets(data,label)
    options = set_title(title)
    
    chart = {
        "type": kind,
        "data":{"labels": labels, "datasets":datasets},
        "options": options
    }
    
    return chart

# %%
def get_api_chart(chart):
    url_base = "https://quickchart.io/chart"
    answer = requests.get(f'{url_base}?c={str(chart)}')
    return answer.content

# %%
def save_image(path, content):
    with open(path,"wb") as image: # Write a binary
        image.write(content)

# %%
from PIL import Image
from IPython.display import display

# %%
def display_image(path):
    img_pil = Image.open(path)
    display(img_pil)

# %%
y_data_1 = []
for obs in final_data[1::10]:
    y_data_1.append(obs[CONFIRMADOS])
    
y_data_2 = []
for obs in final_data[1::10]:
    y_data_2.append(obs[RECUPERADOS])
    
labels = ["Confirmados", "Recuperados"]

x = []
for obs in final_data[1::10]:
    x.append(obs[DATA].strftime("%d/%m/%Y")) # Datetime to string
    
chart = create_chart(x,[y_data_1,y_data_2],labels,title="Gráficos confirmados vs recuperados")
chart_content = get_api_chart(chart)
save_image("meu_primeiro_grafico.png", chart_content)
display_image("meu_primeiro_grafico.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x600 at 0x7F08F0521910>

# %%
from urllib.parse import quote
def get_api_qrcode(link):
    text = quote(link) # parsing do link para a url
    url_base = "https://quickchart.io/qr"
    answer = requests.get("{}?text={}".format(url_base,text))
    return answer.content

# %%
url_base = "https://quickchart.io/chart"
link = "{}?c={}".format(url_base,str(chart))
save_image("qr_code.png", get_api_qrcode(link))
display_image("qr_code.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=676x676 at 0x7F08D2D82970>
